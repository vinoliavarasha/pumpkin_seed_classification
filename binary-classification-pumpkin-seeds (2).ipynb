# %% [markdown]
# # Pumpkin Seed Classification

# %% [markdown]
# * Pumpkin seeds are frequently consumed as confection worldwide because of their adequate amount of protein, fat, carbohydrate, and mineral contents.
#
# * This study was carried out on the two most important and quality types of pumpkin seeds, ‘‘Urgup_Sivrisi’’ and ‘‘Cercevelik’’, generally grown in Urgup and Karacaoren regions in Turkey.
#
# * Morphological measurements of 2500 pumpkin seeds of both varieties were made possible by using the gray and binary forms of threshold techniques.

# %% [markdown]
# # Importing the necessary libraries

# %%
import numpy as np # linear algebra
import pandas as pd# data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the Dataset

# %%
df = pd.read_excel('D:/BATCH_25/random_forest/Pumpkin_Seeds_Dataset/Pumpkin_Seeds_Dataset.xlsx')
df
# Out:
#        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0     56276    888.242           326.1485           220.2388        56831
# 1     76631   1068.146           417.1932           234.2289        77280
# 2     71623   1082.987           435.8328           211.0457        72663
# 3     66458    992.051           381.5638           222.5322        67118
# 4     66107    998.146           383.8883           220.4545        67117
# ...     ...        ...                ...                ...          ...
# 2495  79637   1224.710           533.1513           190.4367        80381
# 2496  69647   1084.318           462.9416           191.8210        70216
# 2497  87994   1210.314           507.2200           222.1872        88702
# 2498  80011   1182.947           501.9065           204.7531        80902
# 2499  84934   1159.933           462.8951           234.5597        85781
#
#       Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  \
# 0           267.6805        0.7376    0.9902  0.7453     0.8963
# 1           312.3614        0.8275    0.9916  0.7151     0.8440
# 2           301.9822        0.8749    0.9857  0.7400     0.7674
# 3           290.8899        0.8123    0.9902  0.7396     0.8486
# 4           290.1207        0.8187    0.9850  0.6752     0.8338
# ...              ...           ...       ...     ...        ...
# 2495        318.4289        0.9340    0.9907  0.4888     0.6672
# 2496        297.7874        0.9101    0.9919  0.6002     0.7444
# 2497        334.7199        0.8990    0.9920  0.7643     0.7549
# 2498        319.1758        0.9130    0.9890  0.7374     0.7185
# 2499        328.8485        0.8621    0.9901  0.7360     0.7933
#
#       Aspect_Ration  Compactness          Class
# 0            1.4809       0.8207     Çerçevelik
# 1            1.7811       0.7487     Çerçevelik
# 2            2.0651       0.6929     Çerçevelik
# 3            1.7146       0.7624     Çerçevelik
# 4            1.7413       0.7557     Çerçevelik
# ...             ...          ...            ...
# 2495         2.7996       0.5973  Ürgüp Sivrisi
# 2496         2.4134       0.6433  Ürgüp Sivrisi
# 2497         2.2828       0.6599  Ürgüp Sivrisi
# 2498         2.4513       0.6359  Ürgüp Sivrisi
# 2499         1.9735       0.7104  Ürgüp Sivrisi
#
# [2500 rows x 13 columns]

# %% [markdown]
# The given dataset is for Pumpkin seeds and we have Class column as the target variable. We have to determine the class of the pumpkin from the features of the pumpkins seeds. The dataset has 12 features for the pumpkin seeds.

# %%
df.isnull().sum()
# Out:
# Area                 0
# Perimeter            0
# Major_Axis_Length    0
# Minor_Axis_Length    0
# Convex_Area          0
# Equiv_Diameter       0
# Eccentricity         0
# Solidity             0
# Extent               0
# Roundness            0
# Aspect_Ration        0
# Compactness          0
# Class                0
# dtype: int64

# %% [markdown]
# As shown the data has no null or missing values so proceeding to do the EDA part

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#                 Area    Perimeter  Major_Axis_Length  Minor_Axis_Length  \
# count    2500.000000  2500.000000        2500.000000        2500.000000
# mean    80658.220800  1130.279015         456.601840         225.794921
# std     13664.510228   109.256418          56.235704          23.297245
# min     47939.000000   868.485000         320.844600         152.171800
# 25%     70765.000000  1048.829750         414.957850         211.245925
# 50%     79076.000000  1123.672000         449.496600         224.703100
# 75%     89757.500000  1203.340500         492.737650         240.672875
# max    136574.000000  1559.450000         661.911300         305.818000
#
#          Convex_Area  Equiv_Diameter  Eccentricity     Solidity       Extent  \
# count    2500.000000     2500.000000   2500.000000  2500.000000  2500.000000
# mean    81508.084400      319.334230      0.860879     0.989492     0.693205
# std     13764.092788       26.891920      0.045167     0.003494     0.060914
# min     48366.000000      247.058400      0.492100     0.918600     0.468000
# 25%     71512.000000      300.167975      0.831700     0.988300     0.658900
# 50%     79872.000000      317.305350      0.863700     0.990300     0.713050
# 75%     90797.750000      338.057375      0.897025     0.991500     0.740225
# max    138384.000000      417.002900      0.948100     0.994400     0.829600
#
#          Roundness  Aspect_Ration  Compactness
# count  2500.000000    2500.000000  2500.000000
# mean      0.791533       2.041702     0.704121
# std       0.055924       0.315997     0.053067
# min       0.554600       1.148700     0.560800
# 25%       0.751900       1.801050     0.663475
# 50%       0.797750       1.984200     0.707700
# 75%       0.834325       2.262075     0.743500
# max       0.939600       3.144400     0.904900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               2500 non-null   int64
#  1   Perimeter          2500 non-null   float64
#  2   Major_Axis_Length  2500 non-null   float64
#  3   Minor_Axis_Length  2500 non-null   float64
#  4   Convex_Area        2500 non-null   int64
#  5   Equiv_Diameter     2500 non-null   float64
#  6   Eccentricity       2500 non-null   float64
#  7   Solidity           2500 non-null   float64
#  8   Extent             2500 non-null   float64
#  9   Roundness          2500 non-null   float64
#  10  Aspect_Ration      2500 non-null   float64
#  11  Compactness        2500 non-null   float64
#  12  Class              2500 non-null   object
# dtypes: float64(10), int64(2), object(1)
# memory usage: 254.0+ KB

# %% [markdown]
# All the features have numerical values. The target variable has string values.

# %% [markdown]
# ## Setting Style for all the Figures

# %%
sns.set(style = 'whitegrid' ,font = 'Rubik', font_scale = 1.1, rc={'axes.facecolor':'#ffffff', 'figure.facecolor':'#ffffff',
                                                                   "axes.spines.right": False, "axes.spines.top": False})

# %% [markdown]
# ### Countplot for the target
# As we can see there are 2 classes and both of the classes have almost equal values

# %%
a = sns.countplot(x = 'Class', data = data, color = 'Green')
a.set_title('Countplot for the 2 Classes')
# Out:
# Text(0.5, 1.0, 'Countplot for the 2 Classes')
# findfont: Font family ['Rubik'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Rubik'] not found. Falling back to DejaVu Sans.

# %%
data['Class'].value_counts()
# Out:
# Çerçevelik       1300
# Ürgüp Sivrisi    1200
# Name: Class, dtype: int64

# %% [markdown]
# # BoxPlots for all featues

# %%
fig, axes = plt.subplots(nrows = 6, ncols = 2, figsize = (20, 40))
for nr, c in enumerate(data.columns):
    if c!= 'Class':
        sns.boxplot(data = data, x = 'Class', y = c, ax = axes[nr // 2, nr % 2], color = 'Green')
        axes[nr // 2, nr % 2].set_title('BoxPlot of ' + c + ' for pumpkin classes')
plt.subplots_adjust(hspace = 0.5, wspace = 0.5)

# %% [markdown]
# As seen in the figures above. We can draw certain conclusions
# * Both the Classes of Pumpkin have different set of values for almost all features except one.
# * The solidity feature is of less importance for us, because the set of values for both classes are same for Solidity.
# * Based on this observation we can drop the solidity column as it is no a distinguishing feature.

# %% [markdown]
# # Seperating into Features and Labels

# %%
X = data.drop('Class', axis = 1)
y = data['Class']

# %%
X.columns
# Out:
# Index(['Area', 'Perimeter', 'Major_Axis_Length', 'Minor_Axis_Length',
#        'Convex_Area', 'Equiv_Diameter', 'Eccentricity', 'Solidity', 'Extent',
#        'Roundness', 'Aspect_Ration', 'Compactness'],
#       dtype='object')

# %%
cols = X.columns
cols
# Out:
# Index(['Area', 'Perimeter', 'Major_Axis_Length', 'Minor_Axis_Length',
#        'Convex_Area', 'Equiv_Diameter', 'Eccentricity', 'Solidity', 'Extent',
#        'Roundness', 'Aspect_Ration', 'Compactness'],
#       dtype='object')

# %% [markdown]
# # CountPlot for all features

# %%
def plot(i, c):
    minm = X[c].min()
    maxm = X[c].max()
    q = (maxm - minm) / 5
    arr = [minm, (minm + q), (minm + 2 * q), (minm + 3 * q), (minm + 4 * q), (minm + 5 * q)]
    a = sns.countplot(x = pd.cut(X[c], arr), data = X, color = 'Green', ax = axes[(i // 2), (i % 2)])
    a.set_title('Countplot for ' + c)

# %%
fig, axes = plt.subplots(nrows = 6, ncols = 2, figsize = (27, 45))
for i in range(12):
    b = cols[i]
    plot(i, b)
plt.subplots_adjust(hspace = 0.4, wspace = 0.2)

# %% [markdown]
# Based on the counplots we can draw conclusions as given below.
# * All the classes have well distributed values.
# * The solidity values are highly skewed and belong in a certain small region only.

# %% [markdown]
# # Correlation plot for all features

# %%
corr = X.corr()
corr.style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_c8ded_row0_col0, #T_c8ded_row0_col4, #T_c8ded_row0_col5, #T_c8ded_row1_col1, #T_c8ded_row2_col2, #T_c8ded_row3_col3, #T_c8ded_row4_col0, #T_c8ded_row4_col4, #T_c8ded_row4_col5, #T_c8ded_row5_col0, #T_c8ded_row5_col4, #T_c8ded_row5_col5, #T_c8ded_row6_col6, #T_c8ded_row7_col7, #T_c8ded_row8_col8, #T_c8ded_row9_col9, #T_c8ded_row10_col10, #T_c8ded_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c8ded_row0_col1, #T_c8ded_row5_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_c8ded_row0_col2, #T_c8ded_row4_col2, #T_c8ded_row5_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_c8ded_row0_col3, #T_c8ded_row3_col11, #T_c8ded_row4_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_c8ded_row0_col6, #T_c8ded_row0_col10, #T_c8ded_row4_col6, #T_c8ded_row4_col10, #T_c8ded_row5_col6, #T_c8ded_row5_col10 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_c8ded_row0_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_c8ded_row0_col8, #T_c8ded_row4_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c8ded_row0_col9, #T_c8ded_row4_col9 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_c8ded_row0_col11, #T_c8ded_row4_col11 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_c8ded_row1_col0, #T_c8ded_row1_col4, #T_c8ded_row1_col5 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_c8ded_row1_col2 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_c8ded_row1_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_c8ded_row1_col6, #T_c8ded_row3_col0, #T_c8ded_row3_col4 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_c8ded_row1_col7, #T_c8ded_row8_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_c8ded_row1_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c8ded_row1_col9 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_c8ded_row1_col10 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_c8ded_row1_col11 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_c8ded_row2_col0, #T_c8ded_row2_col4 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_c8ded_row2_col1 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_c8ded_row2_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c8ded_row2_col5 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_c8ded_row2_col6 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_c8ded_row2_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c8ded_row2_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_c8ded_row2_col9, #T_c8ded_row2_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_c8ded_row2_col10 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_c8ded_row3_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_c8ded_row3_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c8ded_row3_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_c8ded_row3_col6, #T_c8ded_row3_col10 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c8ded_row3_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c8ded_row3_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_c8ded_row3_col9 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_c8ded_row4_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_c8ded_row4_col7 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_c8ded_row5_col3 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_c8ded_row5_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_c8ded_row5_col8, #T_c8ded_row8_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_c8ded_row5_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_c8ded_row5_col11 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_c8ded_row6_col0, #T_c8ded_row6_col4, #T_c8ded_row7_col0, #T_c8ded_row10_col0, #T_c8ded_row10_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_c8ded_row6_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_c8ded_row6_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_c8ded_row6_col3, #T_c8ded_row6_col11, #T_c8ded_row9_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c8ded_row6_col5, #T_c8ded_row7_col5, #T_c8ded_row10_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_c8ded_row6_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c8ded_row6_col8, #T_c8ded_row9_col1, #T_c8ded_row10_col3, #T_c8ded_row10_col8, #T_c8ded_row10_col9, #T_c8ded_row10_col11, #T_c8ded_row11_col0, #T_c8ded_row11_col2, #T_c8ded_row11_col4, #T_c8ded_row11_col5, #T_c8ded_row11_col6, #T_c8ded_row11_col7, #T_c8ded_row11_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c8ded_row6_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c8ded_row6_col10, #T_c8ded_row10_col6 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_c8ded_row7_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_c8ded_row7_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_c8ded_row7_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_c8ded_row7_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_c8ded_row7_col6 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_c8ded_row7_col8 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_c8ded_row7_col9 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_c8ded_row7_col10 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_c8ded_row7_col11 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_c8ded_row8_col0, #T_c8ded_row8_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c8ded_row8_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_c8ded_row8_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c8ded_row8_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_c8ded_row8_col6, #T_c8ded_row8_col10 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_c8ded_row8_col9, #T_c8ded_row8_col11 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_c8ded_row9_col0, #T_c8ded_row9_col5, #T_c8ded_row11_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c8ded_row9_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c8ded_row9_col3 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_c8ded_row9_col6, #T_c8ded_row10_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c8ded_row9_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c8ded_row9_col8 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_c8ded_row9_col10 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c8ded_row9_col11, #T_c8ded_row11_col9 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_c8ded_row10_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_c8ded_row10_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_c8ded_row11_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_c8ded_row11_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# </style>
# <table id="T_c8ded_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Area</th>
#       <th class="col_heading level0 col1" >Perimeter</th>
#       <th class="col_heading level0 col2" >Major_Axis_Length</th>
#       <th class="col_heading level0 col3" >Minor_Axis_Length</th>
#       <th class="col_heading level0 col4" >Convex_Area</th>
#       <th class="col_heading level0 col5" >Equiv_Diameter</th>
#       <th class="col_heading level0 col6" >Eccentricity</th>
#       <th class="col_heading level0 col7" >Solidity</th>
#       <th class="col_heading level0 col8" >Extent</th>
#       <th class="col_heading level0 col9" >Roundness</th>
#       <th class="col_heading level0 col10" >Aspect_Ration</th>
#       <th class="col_heading level0 col11" >Compactness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8ded_level0_row0" class="row_heading level0 row0" >Area</th>
#       <td id="T_c8ded_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c8ded_row0_col1" class="data row0 col1" >0.928548</td>
#       <td id="T_c8ded_row0_col2" class="data row0 col2" >0.789133</td>
#       <td id="T_c8ded_row0_col3" class="data row0 co

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title(' Correlation of Features', y=1.05, size=15)
sns.heatmap(X.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':' Correlation of Features'}>

# %% [markdown]
# As seen in the correlation plot, we can conclude
# * Area feature has a very high correlation with Convex_Area and Equiv_Diameter features
# * Eccentricity and Aspect_Ration have a high correlation
# * Major_Axis_length has a high correlation with Perimeter.
# * We will try to train model after dropping the features of Convex_Area and Solidity

# %%
X1 = X.drop(columns = ['Solidity', 'Convex_Area'], axis = 1)
y1 = data['Class']
X1.head()
# Out:
#     Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Equiv_Diameter  \
# 0  56276    888.242           326.1485           220.2388        267.6805
# 1  76631   1068.146           417.1932           234.2289        312.3614
# 2  71623   1082.987           435.8328           211.0457        301.9822
# 3  66458    992.051           381.5638           222.5322        290.8899
# 4  66107    998.146           383.8883           220.4545        290.1207
#
#    Eccentricity  Extent  Roundness  Aspect_Ration  Compactness
# 0        0.7376  0.7453     0.8963         1.4809       0.8207
# 1        0.8275  0.7151     0.8440         1.7811       0.7487
# 2        0.8749  0.7400     0.7674         2.0651       0.6929
# 3        0.8123  0.7396     0.8486         1.7146       0.7624
# 4        0.8187  0.6752     0.8338         1.7413       0.7557

# %% [markdown]
# # Model Selection

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.2)

# %% [markdown]
# # Functions for Model Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
def model_evaluation(classifier):
    cm = confusion_matrix(y_test, classifier.predict(X_test))
    counts = [value for value in cm.flatten()]
    labels = [f'{v1}' for v1 in counts]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm, annot = labels, cmap = 'Greens', fmt = '')
    y_pred = classifier.predict(X_test)
    yt_pred = classifier.predict(X_train)
    print('The Training Accuracy of the algorithm is ', accuracy_score(y_train, yt_pred))
    print('The Testing Accuracy of the algorithm is ', accuracy_score(y_test, y_pred))
    return [(accuracy_score(y_train * 100, yt_pred * 100) * 100), (accuracy_score(y_test * 100, y_pred * 100) * 100)]

# %%
def model_evaluation1(classifier):
    cm = confusion_matrix(y_test, classifier.predict(X1_test))
    counts = [value for value in cm.flatten()]
    labels = [f'{v1}' for v1 in counts]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm, annot = labels, cmap = 'Blues', fmt = '')
    y1_pred = classifier.predict(X1_test)
    yt1_pred = classifier.predict(X1_train)
    print('The Training Accuracy of the algorithm is ', accuracy_score(y1_train, yt1_pred))
    print('The Testing Accuracy of the algorithm is ', accuracy_score(y1_test, y1_pred))
    return [(accuracy_score(y1_train, yt1_pred) * 100), (accuracy_score(y1_test, y1_pred) * 100)]

# %% [markdown]
# # Note
# * All the models here after will be evaluated on 2 datasets.
# * The first dataset is the one where no column is dropped and the confusion matrix will be plotted in Green Colour.
# * The secodn dataset is the one where some columns are dropped to try improve the accuracy and the confusion matrix for this data will be plotted in Blue Colour.

# %% [markdown]
# # K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(10, weights = 'uniform', metric = 'manhattan')
knn.fit(X_train, y_train)
model_evaluation(knn)
# Out:
# The Training Accuracy of the algorithm is  0.771
# The Testing Accuracy of the algorithm is  0.704
# [77.10000000000001, 70.39999999999999]

# %%
knn1 = KNeighborsClassifier(10, weights = 'uniform', metric = 'manhattan')
knn1.fit(X1_train, y1_train)
model_evaluation1(knn1)
# Out:
# The Training Accuracy of the algorithm is  0.809
# The Testing Accuracy of the algorithm is  0.714
# [80.9, 71.39999999999999]

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
svc = SVC(C = 1E6)
svc.fit(X_train, y_train)
model_evaluation(svc)
# Out:
# The Training Accuracy of the algorithm is  0.8855
# The Testing Accuracy of the algorithm is  0.89
# [88.55, 89.0]

# %%
svc1 = SVC(C = 1E6)
svc1.fit(X1_train, y1_train)
model_evaluation1(svc1)
# Out:
# The Training Accuracy of the algorithm is  0.88
# The Testing Accuracy of the algorithm is  0.87
# [88.0, 87.0]

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
    dt = DecisionTreeClassifier(max_depth = 5)
    dt.fit(X_train, y_train)
    model_evaluation(dt)
# Out:
# The Training Accuracy of the algorithm is  0.898
# The Testing Accuracy of the algorithm is  0.868
# [89.8, 86.8]

# %%
dt1 = DecisionTreeClassifier(max_depth = 5)
dt1.fit(X1_train, y1_train)
model_evaluation1(dt1)
# Out:
# The Training Accuracy of the algorithm is  0.903
# The Testing Accuracy of the algorithm is  0.86
# [90.3, 86.0]

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(max_depth = 4)
rf.fit(X_train, y_train)
model_evaluation(rf)
# Out:
# The Training Accuracy of the algorithm is  0.892
# The Testing Accuracy of the algorithm is  0.876
# [89.2, 87.6]

# %%
rf1 = RandomForestClassifier(max_depth = 4)
rf1.fit(X1_train, y1_train)
model_evaluation1(rf1)
# Out:
# The Training Accuracy of the algorithm is  0.8945
# The Testing Accuracy of the algorithm is  0.858
# [89.45, 85.8]

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(learning_rate = 0.005)
gbc.fit(X_train, y_train)
model_evaluation(gbc)
# Out:
# The Training Accuracy of the algorithm is  0.8855
# The Testing Accuracy of the algorithm is  0.876
# [88.55, 87.6]

# %%
gbc1 = GradientBoostingClassifier(learning_rate = 0.005)
gbc1.fit(X1_train, y1_train)
model_evaluation1(gbc1)
# Out:
# The Training Accuracy of the algorithm is  0.893
# The Testing Accuracy of the algorithm is  0.862
# [89.3, 86.2]

# %%
results1 = pd.DataFrame(columns = ['Training Accuracy Base Model', 'Testing Accuracy Base Model'],index = ['K Nearest Neighbors', 
                                                                                    'Support Vector Machines', 'Decision Tree', 'Random Forest', 'Gradient Boost'])

# %%
results1.loc['K Nearest Neighbors'] = model_evaluation(knn);
results1.loc['Support Vector Machines'] = model_evaluation(svc);
results1.loc['Decision Tree'] = model_evaluation(dt);
results1.loc['Random Forest'] = model_evaluation(rf);
results1.loc['Gradient Boost'] = model_evaluation(gbc);
# Out:
# The Training Accuracy of the algorithm is  0.771
# The Testing Accuracy of the algorithm is  0.704
# The Training Accuracy of the algorithm is  0.8855
# The Testing Accuracy of the algorithm is  0.89
# The Training Accuracy of the algorithm is  0.898
# The Testing Accuracy of the algorithm is  0.868
# The Training Accuracy of the algorithm is  0.892
# The Testing Accuracy of the algorithm is  0.876
# The Training Accuracy of the algorithm is  0.8855
# The Testing Accuracy of the algorithm is  0.876

# %%
results1
# Out:
#                         Training Accuracy Base Model  \
# K Nearest Neighbors                             77.1
# Support Vector Machines                        88.55
# Decision Tree                                   89.8
# Random Forest                                   89.2
# Gradient Boost                                 88.55
#
#                         Testing Accuracy Base Model
# K Nearest Neighbors                            70.4
# Support Vector Machines                        89.0
# Decision Tree                                  86.8
# Random Forest                                  87.6
# Gradient Boost                                 87.6

# %%
results2 = pd.DataFrame(columns = ['Training Accuracy Dropped Columns', 'Testing Accuracy Dropped Columns'],index = ['K Nearest Neighbors', 
                                                                                    'Support Vector Machines', 'Decision Tree', 'Random Forest', 'Gradient Boost'])

# %%
results2.loc['K Nearest Neighbors'] = model_evaluation1(knn1);
results2.loc['Support Vector Machines'] = model_evaluation1(svc1);
results2.loc['Decision Tree'] = model_evaluation1(dt1);
results2.loc['Random Forest'] = model_evaluation1(rf1);
results2.loc['Gradient Boost'] = model_evaluation1(gbc1);
# Out:
# The Training Accuracy of the algorithm is  0.809
# The Testing Accuracy of the algorithm is  0.714
# The Training Accuracy of the algorithm is  0.88
# The Testing Accuracy of the algorithm is  0.87
# The Training Accuracy of the algorithm is  0.903
# The Testing Accuracy of the algorithm is  0.86
# The Training Accuracy of the algorithm is  0.8945
# The Testing Accuracy of the algorithm is  0.858
# The Training Accuracy of the algorithm is  0.893
# The Testing Accuracy of the algorithm is  0.862

# %%
results = pd.concat([results1, results2], join = 'outer', axis = 1)

# %% [markdown]
# # Results

# %%
results
# Out:
#                         Training Accuracy Base Model  \
# K Nearest Neighbors                             77.1
# Support Vector Machines                        88.55
# Decision Tree                                   89.8
# Random Forest                                   89.2
# Gradient Boost                                 88.55
#
#                         Testing Accuracy Base Model  \
# K Nearest Neighbors                            70.4
# Support Vector Machines                        89.0
# Decision Tree                                  86.8
# Random Forest                                  87.6
# Gradient Boost                                 87.6
#
#                         Training Accuracy Dropped Columns  \
# K Nearest Neighbors                                  80.9
# Support Vector Machines                              88.0
# Decision Tree                                        90.3
# Random Forest                                       89.45
# Gradient Boost                                       89.3
#
#                         Testing Accuracy Dropped Columns
# K Nearest Neighbors                                 71.4
# Support Vector Machines                             87.0
# Decision Tree                                       86.0
# Random Forest                                       85.8
# Gradient Boost                                      86.2

# %% [markdown]
# # Conclusion
# * We tried to improve accuracy by dropping colums, but it did not affect the accuracy much.
# * We have achieved good accuracies with SVM, Gradient Boost ,Random Forest Algorithms and Decision Tree.
